# %%
# read in beautiful soup and pandas
from bs4 import BeautifulSoup
import requests
import pandas as pd
import regex as re

# %%
# assign url for main politico page
url = "https://www.politico.com/2020-election/results/house/"
req = requests.get(url)
soup = BeautifulSoup(req.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://www.politico.com/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="https://www.politico.com/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="https://www.politico.com/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="https://www.politico.com/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://www.politico.com/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="https://www.politico.com/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="https://www.politico.com/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="https://www.politico.com/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://www.politico.com/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://www.politico.com/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="https://www.politico.com/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="https://www.politico.com/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="minimum-scale=1, initial-scale=1, width=device-width, shrink-to-fit=no" name="viewport"/>
#   <link href="https://www.politico.com/interactives/cdn/fonts/battletoads/icons/politico-battletoads-icons.min.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.3.1/css/all.css" integrity="sha384-mzrmE5qonljUremFsqc01SB46JvROS7bZs3IO2EmfFsd15uHvIt+Y8vEf7N7fWAU" rel="stylesheet"/>
#   <link href="https://use.typekit.net/dsx2uhv.css" rel="stylesheet"/>
#   <script>
#    try{Typekit.load({ async: true });}catch(e){}
#   </script>
#   <script async="" charset="utf-8" src="https://platform.twitter.com/widgets.js">
#   </script>
#   <style amp-custom="" id="base">
#    @font-face{font-family:'StateFace Regular';src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot");src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot?#iefix") format("embedded-opentype"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.woff") format("woff"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.ttf") format("truetype");font-style:normal;font-weight:normal;}{/*! normalize.css v8.0.1 | MIT License | github.com/necolas/normalize.css */}html{line-height:1.15;-webkit-text-size-adjust:100%;}body{margin:0;}main{display:block;}h1{font-size:2em;margin:0.67em 0;}hr{box-sizing:content-box;height:0;overflow:visible;}pre{font-family:monospace,monospace;font-size:1em;}a{background-color:transparent;}abbr[title]{border-bottom:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-text-decoration:underline dotted;text-decoration:underline dotted;}b,strong{font-weight:bolder;}code,kbd,samp{font-family:monospace,monospace;font-size:1em;}small{font-size:80%;}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline;}sub{bottom:-0.25em;}sup{top:-0.5em;}img{border-style:none;}button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0;}button,input{overflow:visible;}button,select{text-transform:none;}button,[type="button"],[type="reset"],[type="submit"]{-webkit-appearance:button;}button::-moz-focus-inner,[type="button"]::-moz-focus-inner,[type="reset"]::-moz-focus-inner,[type="submit"]::-moz-focus-inner{border-style:none;padding:0;}button:-moz-focusring,[type="button"]:-moz-focusring,[type="reset"]:-moz-focusring,[type="submit"]:-moz-focusring{outline:1px dotted ButtonText;}fieldset{padding:0.35em 0.75em 0.625em;}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal;}progress{vertical-align:baseline;}textarea{overflow:auto;}[type="checkbox"],[type="radio"]{box-sizing:border-box;padding:0;}[type="number"]::-webkit-inner-spin-button,[type="number"]::-webkit-outer-spin-button{height:auto;}[type="search"]{-webkit-appearance:textfield;outline-offset:-2px;}[type="search"]::-webkit-search-decoration{-webkit-appearance:none;}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit;}details{display:block;}summary{display:list-item;}template{display:none;}[hidden]{display:none;}html,body{font-family:"din-2014","Helvetica Neue",Helvetica,Arial,sans-serif;}.fill-politico-red{color:#DC0228;}.fill-politico-red{color:#DC0228;}.fill-politico-red{color:#DC0228;}.stateface:before{font-family:'StateFace Regular';margin-right:5px;}.stateface-replace{text-indent:-999em;display:inline-block;position:relative;min-width:1em;}.stateface-replace:before{position:absolute;left:0;top:0;text-indent:0;}.stateface-ak:before{content:"A";}.stateface-al:before{content:"B";}.stateface-ar:before{content:"C";}.stateface-az:before{content:"D";}.stateface-ca:before{content:"E";}.stateface-co:before{content:"F";}.stateface-ct:before{content:"G";}.stateface-dc:before{content:"y";}.stateface-de:before{content:"H";}.stateface-fl:before{content:"I";}.stateface-ga:before{content:"J";}.stateface-hi:before{content:"K";}.stateface-ia:before{content:"L";}.stateface-id:before{content:"M";}.stateface-il:before{content:"N";}.stateface-in:before{content:"O";}.stateface-ks:before{content:"P";}.stateface-ky:before{content:"Q";}.stateface-la:before{content:"R";}.stateface-ma:before{content:"S";}.stateface-md:before{content:"T";}.stateface-me:before{content:"U";}.stateface-mi:before{content:"V";}.stateface-mn:before{content:"W";}.stateface-mo:before{content:"X";}.stateface-ms:before{content:"Y";}.stateface-mt:before{content:"Z";}.stateface-nc:before{content:"a";}.stateface-nd:before{content:"b";}.stateface-ne:before{content:"c";}.stateface-nh:before{content:"d";}.stateface-nj:before{content:"e";}.stateface-nm:before{con ...
#   </style>
#   <meta content="width=device-width" name="viewport"/>
#   <meta charset="utf-8"/>
#   <title>
#    House Election Results 2020 | Live Map Updates | Voting by State
#   </title>
#   <meta content="https://www.politico.com/2020-election/results/house/" property="og:url"/>
#   <link href="https://www.politico.com/2020-election/results/house/" rel="canonical"/>
#   <meta content="Live 2020 House election results and maps by state. POLITICO's coverage of 2020 races for President, Senate, House, Governors and Key Ballot Measures." name="description"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="article" property="og:type"/>
#   <meta content="false" property="article:opinion"/>
#   <meta content="@politico" property="twitter:site"/>
#   <meta content="@politico" property="twitter:creator"/>
#   <meta content="https://www.facebook.com/politico" property="article:author"/>
#   <meta content="114037015331397" property="fb:app_id"/>
#   <meta content="Live election results: 2020 U.S. House races" property="twitter:title"/>
#   <meta content="Live election results: 2020 U.S. House races" property="og:title"/>
#   <meta content="Track the latest House election results and seat flips alongside live maps and POLITICO’s analysis." property="twitter:description"/>
#   <meta content="Track the latest House election results and seat flips alongside live maps and POLITICO’s analysis." property="og:description"/>
#   <meta content="https://www.politico.com/2020-election/cdn/img/2020-general/share/house.jpg" property="twitter:image"/>
#   <meta content="Live election results: 2020 U.S. House races" property="twitter:image:alt"/>
#   <meta content="https://www.politico.com/2020-election/cdn/img/2020-general/share/house.jpg" property="og:image"/>
#   <meta content="image/jpg" property="og:image:type"/>
#   <meta content="" property="og:image:width"/>
#   <meta content="" property="og:image:height"/>
#   <script async="" charset="utf-8" src="https://platform.twitter.com/widgets.js">
#   </script>
#   <meta content="24" name="next-head-count"/>
#   <link as="script" href="/2020-election/results/_next/static/ookHP4AtUcEq4iVOyqXPR/pages/_app.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/ookHP4AtUcEq4iVOyqXPR/pages/house.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/runtime/webpack-0da7803b01c6aab302c7.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/framework.dcb13c6c2896e64b7ea5.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/commons.5cd6838afae58f8f8e87.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/c50ac3d8a66fb307f7f9036de1b55045392a5954.12eda1bd7e546020f8e7.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/00f5ebd0fabb2bdee7ac1ac5d8f036bf490762e3.7a9ad674ab11e50ced25.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/fc8d6d8698d6869bb695d2f5dac3bf9cb8b30d16.b5f0a7a2388ae006fa3e.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/a6adb3b0b257ceeb71dd59e0d09fdd82935f298f.8bb82c1f99afb37420bb.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/runtime/main-706e444445fd8fec6e08.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/9598fa14.48032d94b585afb50ac1.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/0320ba56.cfb57a8b96f3b999d145.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/b5a2aaf6.645f125407133e30fdd5.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/37120036.cef276aaa8ea78bc8997.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/1832c932f39855380fa904e70e7e680fdf0fac33.b2663fac0f7da312d48e.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/587d8c97d56c7309711fcf17bed99abab4475cb8.77860537361bebd0445c.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/f56ffd422b6f56979f47a1253957f552f20d8ec1.14b65a6a6c8068d295c9.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/b8d007847897f095c6d8bab8e8d1471a26941ecb.331bebd308205da327c3.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/cb169220ee6a99b5e455a5d3d64130af25c95da1.8573dd299f92b438ed7f.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/c7348c6f43d4d389403fb62d6829c3561a663d43.792597c004d33aadb77d.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/f5cfb43b1b1b2d05e15359ba0ac867c07cf293bf.9e14ee493f40baf40676.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/b56cc8cc777fa766ece872936602a9e7be0127ea.c28eb599321f1bfb33f5.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/b7b9d29ca6a3217730f9f0e15f1454d76be7268d.6ef789447c45e4555154.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/b97b7c8883bd44d773cb2e4c164ef576162addbe.e1c0fde5abe5ea8b08c0.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/0c8ef19524b2998c6c0f9417feeb8c55df13c70b.3f25959400240b1d75eb.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/e3c4c3357f6eb6557f3eed604592be73b8099826.c47c4c6866355841eab2.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/80f1ce362748fb162861803bdf95f120093e5a3d.422fbae88876f26dc467.js" rel="preload"/>
#   <link as="script" href="/2020-election/results/_next/static/chunks/5c25a6f799cc4ab6f45ce0cc9d9e71637e0c3f10.4ab6a50bd991a3bdb638.js" rel="preload"/>
#   <style id="__jsx-2466726094">
#    @font-face{font-family:'StateFace Regular';src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot");src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot?#iefix") format("embedded-opentype"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.woff") format("woff"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.ttf") format("truetype");font-style:normal;font-weight:normal;}.fill-politico-red.jsx-2466726094{color:#DC0228;}.fill-politico-red.jsx-2466726094{color:#DC0228;}.fill-politico-red.jsx-2466726094{color:#DC0228;}.stateface.jsx-2466726094:before{font-family:'StateFace Regular';margin-right:5px;}.stateface-replace.jsx-2466726094{text-indent:-999em;display:inline-block;position:relative;min-width:1em;}.stateface-replace.jsx-2466726094:before{position:absolute;left:0;top:0;text-indent:0;}.stateface-ak.jsx-2466726094:before{content:"A";}.stateface-al.jsx-2466726094:before{content:"B";}.stateface-ar.jsx-2466726094:before{content:"C";}.stateface-az.jsx-2466726094:before{content:"D";}.stateface-ca.jsx-2466726094:before{content:"E";}.stateface-co.jsx-2466726094:before{content:"F";}.stateface-ct.jsx-2466726094:before{content:"G";}.stateface-dc.jsx-2466726094:before{content:"y";}.stateface-de.jsx-2466726094:before{content:"H";}.stateface-fl.jsx-2466726094:before{content:"I";}.stateface-ga.jsx-2466726094:before{content:"J";}.stateface-hi.jsx-2466726094:before{content:"K";}.stateface-ia.jsx-2466726094:before{content:"L";}.stateface-id.jsx-2466726094:before{content:"M";}.stateface-il.jsx-2466726094:before{content:"N";}.stateface-in.jsx-2466726094:before{content:"O";}.stateface-ks.jsx-2466726094:before{content:"P";}.stateface-ky.jsx-2466726094:before{content:"Q";}.stateface-la.jsx-2466726094:before{content:"R";}.stateface-ma.jsx-2466726094:before{content:"S";}.stateface-md.jsx-2466726094:before{content:"T";}.stateface-me.jsx-2466726094:before{content:"U";}.stateface-mi.jsx-2466726094:before{content:"V";}.stateface-mn.jsx-2466726094:before{content:"W";}.stateface-mo.jsx-2466726094:before{content:"X";}.stateface-ms.jsx-2466726094:before{content:"Y";}.stateface-mt.jsx-2466726094:before{content:"Z";}.stateface-nc.jsx-2466726094:before{content:"a";}.stateface-nd.jsx-2466726094:before{content:"b";}.stateface-ne.jsx-2466726094:before{content:"c";}.stateface-nh.jsx-2466726094:before{content:"d";}.stateface-nj.jsx-2466726094:before{content:"e";}.stateface-nm.jsx-2466726094:before{content:"f";}.stateface-nv.jsx-2466726094:before{content:"g";}.stateface-ny.jsx-2466726094:before{content:"h";}.stateface-oh.jsx-2466726094:before{content:"i";}.stateface-ok.jsx-2466726094:before{content:"j";}.stateface-or.jsx-2466726094:before{content:"k";}.stateface-pa.jsx-2466726094:before{content:"l";}.stateface-ri.jsx-2466726094:before{content:"m";}.stateface-sc.jsx-2466726094:before{content:"n";}.stateface-sd.jsx-2466726094:before{content:"o";}.stateface-tn.jsx-2466726094:before{content:"p";}.stateface-tx.jsx-2466726094:before{content:"q";}.stateface-us.jsx-2466726094:before{content:"z";}.stateface-ut.jsx-2466726094:before{content:"r";}.stateface-va.jsx-2466726094:before{content:"s";}.stateface-vt.jsx-2466726094:before{content:"t";}.stateface-wa.jsx-2466726094:before{content:"u";}.stateface-wi.jsx-2466726094:before{content:"v";}.stateface-wv.jsx-2466726094:before{content:"w";}.stateface-wy.jsx-2466726094:before{content:"x";}.loading-screen.jsx-2466726094{position:fixed;top:0;bottom:0;left:0;right:0;height:100%;width:100%;background-color:white;z-index:999999;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}.election-results-logo.jsx-24667 ...
#   </style>
#   <style id="__jsx-225004194">
#    .fill-politico-red.jsx-225004194{color:#DC0228;}.ad-placeholder__rect.jsx-225004194{width:600px;height:90px;margin:5px auto 0;background-color:#f4f5f7;}
#   </style>
#   <style id="__jsx-500863524">
#    .fill-politico-red.jsx-500863524{color:#DC0228;}.ad-container.jsx-500863524 .fill-politico-red.jsx-500863524{color:#DC0228;}.ad-container.jsx-500863524 .content-group.ad.jsx-500863524{text-align:center;margin:0px auto;padding:30px 0;}.ad-container.jsx-500863524 .content-group.ad.jsx-500863524 .ad-slot.flex.jsx-500863524{text-align:center;}.ad-container.jsx-500863524 .content-group.ad.jsx-500863524 p.jsx-500863524{text-transform:uppercase;font-family:"din-2014","Helvetica Neue",Helvetica,Arial,sans-serif;font-variant-ligatures:none;font-size:12px;color:#6E7381;margin:5px auto 0;}.ad-container.jsx-500863524 .ad.supercube.jsx-500863524,.ad-container.jsx-500863524 .ad.cube.jsx-500863524{padding-top:35px;padding-bottom:35px;max-width:600px;}.PibAd-container.jsx-500863524{width:100%;text-align:center;margin:0 auto;padding:30px 0;}.PibAd-disclaimer.jsx-500863524{text-transform:uppercase;font-family:"din-2014","Helvetica Neue",Helvetica,Arial,sans-serif;font-variant-ligatures:none;font-size:12px;color:#6e7381;margin:5px auto 0;}.PibAd-root.jsx-500863524{text-align:center;}
#   </style>
#   <style id="__jsx-3199254626">
#    @font-face{font-family:'StateFace Regular';src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot");src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot?#iefix") format("embedded-opentype"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.woff") format("woff"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.ttf") format("truetype");font-style:normal;font-weight:normal;}.fill-politico-red.jsx-3199254626{color:#DC0228;}.fill-politico-red.jsx-3199254626{color:#DC0228;}.fill-politico-red.jsx-3199254626{color:#DC0228;}.stateface.jsx-3199254626:before{font-family:'StateFace Regular';margin-right:5px;}.stateface-replace.jsx-3199254626{text-indent:-999em;display:inline-block;position:relative;min-width:1em;}.stateface-replace.jsx-3199254626:before{position:absolute;left:0;top:0;text-indent:0;}.stateface-ak.jsx-3199254626:before{content:"A";}.stateface-al.jsx-3199254626:before{content:"B";}.stateface-ar.jsx-3199254626:before{content:"C";}.stateface-az.jsx-3199254626:before{content:"D";}.stateface-ca.jsx-3199254626:before{content:"E";}.stateface-co.jsx-3199254626:before{content:"F";}.stateface-ct.jsx-3199254626:before{content:"G";}.stateface-dc.jsx-3199254626:before{content:"y";}.stateface-de.jsx-3199254626:before{content:"H";}.stateface-fl.jsx-3199254626:before{content:"I";}.stateface-ga.jsx-3199254626:before{content:"J";}.stateface-hi.jsx-3199254626:before{content:"K";}.stateface-ia.jsx-3199254626:before{content:"L";}.stateface-id.jsx-3199254626:before{content:"M";}.stateface-il.jsx-3199254626:before{content:"N";}.stateface-in.jsx-3199254626:before{content:"O";}.stateface-ks.jsx-3199254626:before{content:"P";}.stateface-ky.jsx-3199254626:before{content:"Q";}.stateface-la.jsx-3199254626:before{content:"R";}.stateface-ma.jsx-3199254626:before{content:"S";}.stateface-md.jsx-3199254626:before{content:"T";}.stateface-me.jsx-3199254626:before{content:"U";}.stateface-mi.jsx-3199254626:before{content:"V";}.stateface-mn.jsx-3199254626:before{content:"W";}.stateface-mo.jsx-3199254626:before{content:"X";}.stateface-ms.jsx-3199254626:before{content:"Y";}.stateface-mt.jsx-3199254626:before{content:"Z";}.stateface-nc.jsx-3199254626:before{content:"a";}.stateface-nd.jsx-3199254626:before{content:"b";}.stateface-ne.jsx-3199254626:before{content:"c";}.stateface-nh.jsx-3199254626:before{content:"d";}.stateface-nj.jsx-3199254626:before{content:"e";}.stateface-nm.jsx-3199254626:before{content:"f";}.stateface-nv.jsx-3199254626:before{content:"g";}.stateface-ny.jsx-3199254626:before{content:"h";}.stateface-oh.jsx-3199254626:before{content:"i";}.stateface-ok.jsx-3199254626:before{content:"j";}.stateface-or.jsx-3199254626:before{content:"k";}.stateface-pa.jsx-3199254626:before{content:"l";}.stateface-ri.jsx-3199254626:before{content:"m";}.stateface-sc.jsx-3199254626:before{content:"n";}.stateface-sd.jsx-3199254626:before{content:"o";}.stateface-tn.jsx-3199254626:before{content:"p";}.stateface-tx.jsx-3199254626:before{content:"q";}.stateface-us.jsx-3199254626:before{content:"z";}.stateface-ut.jsx-3199254626:before{content:"r";}.stateface-va.jsx-3199254626:before{content:"s";}.stateface-vt.jsx-3199254626:before{content:"t";}.stateface-wa.jsx-3199254626:before{content:"u";}.stateface-wi.jsx-3199254626:before{content:"v";}.stateface-wv.jsx-3199254626:before{content:"w";}.stateface-wy.jsx-3199254626:before{content:"x";}.election-ad.jsx-3199254626{margin-top:calc(64px - 30px);margin-bottom:calc(64px - 30px);}.election-ad.slim.jsx-3199254626{margin-top:0;margin-bottom:0;}.election-ad.jsx-3199254626 .ad-placeholder__rect{max-width:600px;width:auto;}
#   </style>
#   <style id="__jsx-1280865285">
#    .fill-politico-red.jsx-1280865285{color:#DC0228;}.navigation.jsx-1280865285{position:relative;}.navigation.jsx-1280865285 .fill-politico-red.jsx-1280865285{color:#DC0228;}.navigation.jsx-1280865285 a.jsx-1280865285{-webkit-text-decoration:none;text-decoration:none;}.navigation.jsx-1280865285 a.jsx-1280865285:hover,.navigation.jsx-1280865285 a.jsx-1280865285:active,.navigation.jsx-1280865285 a.jsx-1280865285:focus{-webkit-text-decoration:none;text-decoration:none;}.navigation.jsx-1280865285 .micro-list.jsx-1280865285 a.jsx-1280865285{color:rgba(0,0,0,0.85);}.navigation.jsx-1280865285 .PibNavigation-root.jsx-1280865285{background:transparent;border-bottom:1px solid rgba(180,180,180,0.35);}.navigation.jsx-1280865285 .PibNavigation-root.jsx-1280865285::after{clear:both;content:'';display:table;}.navigation.jsx-1280865285 .PibNavigation-root.dark.jsx-1280865285{background-color:#23252d;}.navigation.jsx-1280865285 .PibNavigation-root.dark.jsx-1280865285 .bt-icon--magazine.jsx-1280865285{color:white;}.navigation.jsx-1280865285 .PibNavigation-root.dark.jsx-1280865285 a.jsx-1280865285 svg.jsx-1280865285{fill:white;}.navigation.jsx-1280865285 .PibNavigation-root.dark.jsx-1280865285 .micro-list.jsx-1280865285 a.jsx-1280865285{color:white;}.navigation.jsx-1280865285 .PibNavigation-root.light.jsx-1280865285{background-color:transparent;}.navigation.jsx-1280865285 .PibNavigation-root.light.jsx-1280865285 .bt-icon--magazine.jsx-1280865285{color:black;}.navigation.jsx-1280865285 .PibNavigation-root.light.jsx-1280865285 a.jsx-1280865285 svg.jsx-1280865285{fill:black;}.navigation.jsx-1280865285 .PibNavigation-root.light.jsx-1280865285 a.jsx-1280865285{color:black;}.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 .PibNavigation-branding.jsx-1280865285{left:52%;}@media (min-width:350px){.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 .PibNavigation-branding.jsx-1280865285{left:50%;}}.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 .bt-icon--politico.jsx-1280865285{font-size:1rem;}@media (min-width:350px){.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 .bt-icon--politico.jsx-1280865285{font-size:1.2rem;margin-top:0;}}@media (min-width:650px){.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 .bt-icon--politico.jsx-1280865285{font-size:1.8rem;margin:5px 0 15px;padding:0;}}@media (min-width:992px){.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 .bt-icon--politico.jsx-1280865285{font-size:2.5rem;margin:5px 0 15px;padding:0;}}.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 .bt-icon--magazine.jsx-1280865285{font-size:1rem;}@media (min-width:350px){.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 .bt-icon--magazine.jsx-1280865285{font-size:1.2rem;margin-top:0;}}@media (min-width:650px){.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 .bt-icon--magazine.jsx-1280865285{font-size:1.6rem;margin:5px 0 15px;padding:0;}}@media (min-width:992px){.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 .bt-icon--magazine.jsx-1280865285{font-size:2.3rem;margin:5px 0 15px;padding:0;}}.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 a.jsx-1280865285:hover,.navigation.jsx-1280865285 .PibNavigation-root.magazine.jsx-1280865285 a.jsx-1280865285:focus{-webkit-text-decoration:none;text-decoration:none;opacity:0.8;}.navigation.jsx-1280865285 .PibNavigation-root.jsx-1280865285 .PibNavigation-root.jsx-1280865285::after,.navigation.jsx-1280865285 .PibNavigation-root.jsx-1280865285 ul.jsx-1280865285::after{clear:both;content:'';display:table;}.navigation.jsx-1280865285 .PibNavigation-root.jsx-1280865285 .header-contents.jsx-1280865285{padding:0 1rem;}.navigation.jsx-1280865285 .PibNavigation-root.jsx-1280865285 .bt-icon--house.jsx-1280865285 svg.jsx-1280865285{height:25px;}.navigation.jsx-1280865285 .PibNavigation-root.jsx-1280865285 .bt-ic ...
#   </style>
#   <style id="__jsx-3605130982">
#    @font-face{font-family:'StateFace Regular';src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot");src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot?#iefix") format("embedded-opentype"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.woff") format("woff"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.ttf") format("truetype");font-style:normal;font-weight:normal;}.fill-politico-red.jsx-3605130982{color:#DC0228;}.fill-politico-red.jsx-3605130982{color:#DC0228;}.fill-politico-red.jsx-3605130982{color:#DC0228;}.stateface.jsx-3605130982:before{font-family:'StateFace Regular';margin-right:5px;}.stateface-replace.jsx-3605130982{text-indent:-999em;display:inline-block;position:relative;min-width:1em;}.stateface-replace.jsx-3605130982:before{position:absolute;left:0;top:0;text-indent:0;}.stateface-ak.jsx-3605130982:before{content:"A";}.stateface-al.jsx-3605130982:before{content:"B";}.stateface-ar.jsx-3605130982:before{content:"C";}.stateface-az.jsx-3605130982:before{content:"D";}.stateface-ca.jsx-3605130982:before{content:"E";}.stateface-co.jsx-3605130982:before{content:"F";}.stateface-ct.jsx-3605130982:before{content:"G";}.stateface-dc.jsx-3605130982:before{content:"y";}.stateface-de.jsx-3605130982:before{content:"H";}.stateface-fl.jsx-3605130982:before{content:"I";}.stateface-ga.jsx-3605130982:before{content:"J";}.stateface-hi.jsx-3605130982:before{content:"K";}.stateface-ia.jsx-3605130982:before{content:"L";}.stateface-id.jsx-3605130982:before{content:"M";}.stateface-il.jsx-3605130982:before{content:"N";}.stateface-in.jsx-3605130982:before{content:"O";}.stateface-ks.jsx-3605130982:before{content:"P";}.stateface-ky.jsx-3605130982:before{content:"Q";}.stateface-la.jsx-3605130982:before{content:"R";}.stateface-ma.jsx-3605130982:before{content:"S";}.stateface-md.jsx-3605130982:before{content:"T";}.stateface-me.jsx-3605130982:before{content:"U";}.stateface-mi.jsx-3605130982:before{content:"V";}.stateface-mn.jsx-3605130982:before{content:"W";}.stateface-mo.jsx-3605130982:before{content:"X";}.stateface-ms.jsx-3605130982:before{content:"Y";}.stateface-mt.jsx-3605130982:before{content:"Z";}.stateface-nc.jsx-3605130982:before{content:"a";}.stateface-nd.jsx-3605130982:before{content:"b";}.stateface-ne.jsx-3605130982:before{content:"c";}.stateface-nh.jsx-3605130982:before{content:"d";}.stateface-nj.jsx-3605130982:before{content:"e";}.stateface-nm.jsx-3605130982:before{content:"f";}.stateface-nv.jsx-3605130982:before{content:"g";}.stateface-ny.jsx-3605130982:before{content:"h";}.stateface-oh.jsx-3605130982:before{content:"i";}.stateface-ok.jsx-3605130982:before{content:"j";}.stateface-or.jsx-3605130982:before{content:"k";}.stateface-pa.jsx-3605130982:before{content:"l";}.stateface-ri.jsx-3605130982:before{content:"m";}.stateface-sc.jsx-3605130982:before{content:"n";}.stateface-sd.jsx-3605130982:before{content:"o";}.stateface-tn.jsx-3605130982:before{content:"p";}.stateface-tx.jsx-3605130982:before{content:"q";}.stateface-us.jsx-3605130982:before{content:"z";}.stateface-ut.jsx-3605130982:before{content:"r";}.stateface-va.jsx-3605130982:before{content:"s";}.stateface-vt.jsx-3605130982:before{content:"t";}.stateface-wa.jsx-3605130982:before{content:"u";}.stateface-wi.jsx-3605130982:before{content:"v";}.stateface-wv.jsx-3605130982:before{content:"w";}.stateface-wy.jsx-3605130982:before{content:"x";}.pullout-toggle.jsx-3605130982{background:#ffffff;border:1px solid #DADADA;border-radius:16px;box-sizing:border-box;color:#CCCCCC;cursor:pointer;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;font-size:14px;height:32px;line-height:30px;outline:none;padding:0;position:relative;text-align:center;width:32px;}.pullout-toggle.is-tablet.jsx-3605130982,.pullout-toggle.is-desktop.jsx-3605130982{margin-top:6px;}.pullout-toggle.jsx-36051309 ...
#   </style>
#   <style id="__jsx-2170904326">
#    .bop-heading.jsx-2170904326{font-size:11px;height:11px;-webkit-letter-spacing:0.75px;-moz-letter-spacing:0.75px;-ms-letter-spacing:0.75px;letter-spacing:0.75px;line-height:11px;margin:0 0 4px;-webkit-order:1;-ms-flex-order:1;order:1;text-transform:uppercase;}.is-tablet.jsx-2170904326,.is-desktop.jsx-2170904326{font-size:inherit;height:19px;-webkit-letter-spacing:0.25px;-moz-letter-spacing:0.25px;-ms-letter-spacing:0.25px;letter-spacing:0.25px;line-height:19px;text-transform:none;}.in-pullout.jsx-2170904326{font-size:inherit;height:16px;-webkit-letter-spacing:0;-moz-letter-spacing:0;-ms-letter-spacing:0;letter-spacing:0;line-height:19px;margin:0 0 4px;text-transform:none;width:50%;}.in-pullout.body-house.jsx-2170904326,.in-pullout.body-senate.jsx-2170904326{width:100%;}
#   </style>
#   <style id="__jsx-45013479">
#    @font-face{font-family:'StateFace Regular';src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot");src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot?#iefix") format("embedded-opentype"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.woff") format("woff"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.ttf") format("truetype");font-style:normal;font-weight:normal;}.fill-politico-red.jsx-45013479{color:#DC0228;}.fill-politico-red.jsx-45013479{color:#DC0228;}.fill-politico-red.jsx-45013479{color:#DC0228;}.stateface.jsx-45013479:before{font-family:'StateFace Regular';margin-right:5px;}.stateface-replace.jsx-45013479{text-indent:-999em;display:inline-block;position:relative;min-width:1em;}.stateface-replace.jsx-45013479:before{position:absolute;left:0;top:0;text-indent:0;}.stateface-ak.jsx-45013479:before{content:"A";}.stateface-al.jsx-45013479:before{content:"B";}.stateface-ar.jsx-45013479:before{content:"C";}.stateface-az.jsx-45013479:before{content:"D";}.stateface-ca.jsx-45013479:before{content:"E";}.stateface-co.jsx-45013479:before{content:"F";}.stateface-ct.jsx-45013479:before{content:"G";}.stateface-dc.jsx-45013479:before{content:"y";}.stateface-de.jsx-45013479:before{content:"H";}.stateface-fl.jsx-45013479:before{content:"I";}.stateface-ga.jsx-45013479:before{content:"J";}.stateface-hi.jsx-45013479:before{content:"K";}.stateface-ia.jsx-45013479:before{content:"L";}.stateface-id.jsx-45013479:before{content:"M";}.stateface-il.jsx-45013479:before{content:"N";}.stateface-in.jsx-45013479:before{content:"O";}.stateface-ks.jsx-45013479:before{content:"P";}.stateface-ky.jsx-45013479:before{content:"Q";}.stateface-la.jsx-45013479:before{content:"R";}.stateface-ma.jsx-45013479:before{content:"S";}.stateface-md.jsx-45013479:before{content:"T";}.stateface-me.jsx-45013479:before{content:"U";}.stateface-mi.jsx-45013479:before{content:"V";}.stateface-mn.jsx-45013479:before{content:"W";}.stateface-mo.jsx-45013479:before{content:"X";}.stateface-ms.jsx-45013479:before{content:"Y";}.stateface-mt.jsx-45013479:before{content:"Z";}.stateface-nc.jsx-45013479:before{content:"a";}.stateface-nd.jsx-45013479:before{content:"b";}.stateface-ne.jsx-45013479:before{content:"c";}.stateface-nh.jsx-45013479:before{content:"d";}.stateface-nj.jsx-45013479:before{content:"e";}.stateface-nm.jsx-45013479:before{content:"f";}.stateface-nv.jsx-45013479:before{content:"g";}.stateface-ny.jsx-45013479:before{content:"h";}.stateface-oh.jsx-45013479:before{content:"i";}.stateface-ok.jsx-45013479:before{content:"j";}.stateface-or.jsx-45013479:before{content:"k";}.stateface-pa.jsx-45013479:before{content:"l";}.stateface-ri.jsx-45013479:before{content:"m";}.stateface-sc.jsx-45013479:before{content:"n";}.stateface-sd.jsx-45013479:before{content:"o";}.stateface-tn.jsx-45013479:before{content:"p";}.stateface-tx.jsx-45013479:before{content:"q";}.stateface-us.jsx-45013479:before{content:"z";}.stateface-ut.jsx-45013479:before{content:"r";}.stateface-va.jsx-45013479:before{content:"s";}.stateface-vt.jsx-45013479:before{content:"t";}.stateface-wa.jsx-45013479:before{content:"u";}.stateface-wi.jsx-45013479:before{content:"v";}.stateface-wv.jsx-45013479:before{content:"w";}.stateface-wy.jsx-45013479:before{content:"x";}.icon.small-sized.jsx-45013479{line-height:11px;}.checkMark.jsx-45013479{stroke:#B1B4BD;}.checkMark.affirmative-choice.jsx-45013479{stroke:#75CCCA;}.checkMark.negative-choice.jsx-45013479{stroke:#EF8B67;}.checkMark.dem.jsx-45013479{stroke:#3571C0;}.checkMark.gop.jsx-45013479{stroke:#FE5C40;}.checkMark.grn.jsx-45013479{stroke:#8ABDC0;}.checkMark.ind.jsx-45013479{stroke:#8ABDC0;}.checkMark.lib.jsx-45013479{stroke:#8ABDC0;}
#   </style>
#   <style id="__jsx-1322400979">
#    @font-face{font-family:'StateFace Regular';src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot");src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot?#iefix") format("embedded-opentype"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.woff") format("woff"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.ttf") format("truetype");font-style:normal;font-weight:normal;}.fill-politico-red.jsx-1322400979{color:#DC0228;}.fill-politico-red.jsx-1322400979{color:#DC0228;}.fill-politico-red.jsx-1322400979{color:#DC0228;}.stateface.jsx-1322400979:before{font-family:'StateFace Regular';margin-right:5px;}.stateface-replace.jsx-1322400979{text-indent:-999em;display:inline-block;position:relative;min-width:1em;}.stateface-replace.jsx-1322400979:before{position:absolute;left:0;top:0;text-indent:0;}.stateface-ak.jsx-1322400979:before{content:"A";}.stateface-al.jsx-1322400979:before{content:"B";}.stateface-ar.jsx-1322400979:before{content:"C";}.stateface-az.jsx-1322400979:before{content:"D";}.stateface-ca.jsx-1322400979:before{content:"E";}.stateface-co.jsx-1322400979:before{content:"F";}.stateface-ct.jsx-1322400979:before{content:"G";}.stateface-dc.jsx-1322400979:before{content:"y";}.stateface-de.jsx-1322400979:before{content:"H";}.stateface-fl.jsx-1322400979:before{content:"I";}.stateface-ga.jsx-1322400979:before{content:"J";}.stateface-hi.jsx-1322400979:before{content:"K";}.stateface-ia.jsx-1322400979:before{content:"L";}.stateface-id.jsx-1322400979:before{content:"M";}.stateface-il.jsx-1322400979:before{content:"N";}.stateface-in.jsx-1322400979:before{content:"O";}.stateface-ks.jsx-1322400979:before{content:"P";}.stateface-ky.jsx-1322400979:before{content:"Q";}.stateface-la.jsx-1322400979:before{content:"R";}.stateface-ma.jsx-1322400979:before{content:"S";}.stateface-md.jsx-1322400979:before{content:"T";}.stateface-me.jsx-1322400979:before{content:"U";}.stateface-mi.jsx-1322400979:before{content:"V";}.stateface-mn.jsx-1322400979:before{content:"W";}.stateface-mo.jsx-1322400979:before{content:"X";}.stateface-ms.jsx-1322400979:before{content:"Y";}.stateface-mt.jsx-1322400979:before{content:"Z";}.stateface-nc.jsx-1322400979:before{content:"a";}.stateface-nd.jsx-1322400979:before{content:"b";}.stateface-ne.jsx-1322400979:before{content:"c";}.stateface-nh.jsx-1322400979:before{content:"d";}.stateface-nj.jsx-1322400979:before{content:"e";}.stateface-nm.jsx-1322400979:before{content:"f";}.stateface-nv.jsx-1322400979:before{content:"g";}.stateface-ny.jsx-1322400979:before{content:"h";}.stateface-oh.jsx-1322400979:before{content:"i";}.stateface-ok.jsx-1322400979:before{content:"j";}.stateface-or.jsx-1322400979:before{content:"k";}.stateface-pa.jsx-1322400979:before{content:"l";}.stateface-ri.jsx-1322400979:before{content:"m";}.stateface-sc.jsx-1322400979:before{content:"n";}.stateface-sd.jsx-1322400979:before{content:"o";}.stateface-tn.jsx-1322400979:before{content:"p";}.stateface-tx.jsx-1322400979:before{content:"q";}.stateface-us.jsx-1322400979:before{content:"z";}.stateface-ut.jsx-1322400979:before{content:"r";}.stateface-va.jsx-1322400979:before{content:"s";}.stateface-vt.jsx-1322400979:before{content:"t";}.stateface-wa.jsx-1322400979:before{content:"u";}.stateface-wi.jsx-1322400979:before{content:"v";}.stateface-wv.jsx-1322400979:before{content:"w";}.stateface-wy.jsx-1322400979:before{content:"x";}.bar-section.jsx-1322400979{background-color:#D8D8D8;height:4px;list-style:none inside;width:8px;}.called-d-section.jsx-1322400979{background-color:#3571C0;}.called-r-section.jsx-1322400979{background-color:#FE5C40;}.seated-d-section.jsx-1322400979{background-color:#183862;}.seated-r-section.jsx-1322400979{background-color:#A3311D;}.is-tablet.jsx-1322400979,.is-desktop.jsx-1322400979,.thick.jsx-1322400979{height:8px;}
#   </style>
#   <style id="__jsx-2148337571">
#    .balance-bar.jsx-2148337571{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin:0;-webkit-order:3;-ms-flex-order:3;order:3;width:100%;padding:0;}.is-tablet.jsx-2148337571,.is-desktop.jsx-2148337571,.in-pullout.jsx-2148337571{-webkit-order:4;-ms-flex-order:4;order:4;}
#   </style>
#   <style id="__jsx-522859858">
#    @font-face{font-family:'StateFace Regular';src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot");src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot?#iefix") format("embedded-opentype"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.woff") format("woff"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.ttf") format("truetype");font-style:normal;font-weight:normal;}.fill-politico-red.jsx-522859858{color:#DC0228;}.fill-politico-red.jsx-522859858{color:#DC0228;}.fill-politico-red.jsx-522859858{color:#DC0228;}.stateface.jsx-522859858:before{font-family:'StateFace Regular';margin-right:5px;}.stateface-replace.jsx-522859858{text-indent:-999em;display:inline-block;position:relative;min-width:1em;}.stateface-replace.jsx-522859858:before{position:absolute;left:0;top:0;text-indent:0;}.stateface-ak.jsx-522859858:before{content:"A";}.stateface-al.jsx-522859858:before{content:"B";}.stateface-ar.jsx-522859858:before{content:"C";}.stateface-az.jsx-522859858:before{content:"D";}.stateface-ca.jsx-522859858:before{content:"E";}.stateface-co.jsx-522859858:before{content:"F";}.stateface-ct.jsx-522859858:before{content:"G";}.stateface-dc.jsx-522859858:before{content:"y";}.stateface-de.jsx-522859858:before{content:"H";}.stateface-fl.jsx-522859858:before{content:"I";}.stateface-ga.jsx-522859858:before{content:"J";}.stateface-hi.jsx-522859858:before{content:"K";}.stateface-ia.jsx-522859858:before{content:"L";}.stateface-id.jsx-522859858:before{content:"M";}.stateface-il.jsx-522859858:before{content:"N";}.stateface-in.jsx-522859858:before{content:"O";}.stateface-ks.jsx-522859858:before{content:"P";}.stateface-ky.jsx-522859858:before{content:"Q";}.stateface-la.jsx-522859858:before{content:"R";}.stateface-ma.jsx-522859858:before{content:"S";}.stateface-md.jsx-522859858:before{content:"T";}.stateface-me.jsx-522859858:before{content:"U";}.stateface-mi.jsx-522859858:before{content:"V";}.stateface-mn.jsx-522859858:before{content:"W";}.stateface-mo.jsx-522859858:before{content:"X";}.stateface-ms.jsx-522859858:before{content:"Y";}.stateface-mt.jsx-522859858:before{content:"Z";}.stateface-nc.jsx-522859858:before{content:"a";}.stateface-nd.jsx-522859858:before{content:"b";}.stateface-ne.jsx-522859858:before{content:"c";}.stateface-nh.jsx-522859858:before{content:"d";}.stateface-nj.jsx-522859858:before{content:"e";}.stateface-nm.jsx-522859858:before{content:"f";}.stateface-nv.jsx-522859858:before{content:"g";}.stateface-ny.jsx-522859858:before{content:"h";}.stateface-oh.jsx-522859858:before{content:"i";}.stateface-ok.jsx-522859858:before{content:"j";}.stateface-or.jsx-522859858:before{content:"k";}.stateface-pa.jsx-522859858:before{content:"l";}.stateface-ri.jsx-522859858:before{content:"m";}.stateface-sc.jsx-522859858:before{content:"n";}.stateface-sd.jsx-522859858:before{content:"o";}.stateface-tn.jsx-522859858:before{content:"p";}.stateface-tx.jsx-522859858:before{content:"q";}.stateface-us.jsx-522859858:before{content:"z";}.stateface-ut.jsx-522859858:before{content:"r";}.stateface-va.jsx-522859858:before{content:"s";}.stateface-vt.jsx-522859858:before{content:"t";}.stateface-wa.jsx-522859858:before{content:"u";}.stateface-wi.jsx-522859858:before{content:"v";}.stateface-wv.jsx-522859858:before{content:"w";}.stateface-wy.jsx-522859858:before{content:"x";}.win-lead-description.jsx-522859858{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;color:#B1B4BD;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-size:11px;font-weight:400;height:11px;-webkit-letter-spacing:1.25px;-moz-letter-spacing:1.25px;-ms-letter-spacing:1.25px;letter-spacing:1.25px;line-height:11px;margin:4px 0 0;-webkit-order:4;-ms-flex-order:4;order:4;width:100%;text-transform:uppercase;}.win-lead-description.dem-shading.jsx-522859858{color:#3571C0;}.win-lead-descript ...
#   </style>
#   <style id="__jsx-3251934667">
#    @font-face{font-family:'StateFace Regular';src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot");src:url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.eot?#iefix") format("embedded-opentype"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.woff") format("woff"),url("https://unpkg.com/dmn-stateface@1.0.2/font/webfont/stateface-regular-webfont.ttf") format("truetype");font-style:normal;font-weight:normal;}.fill-politico-red.jsx-3251934667{color:#DC0228;}.fill-politico-red.jsx-3251934667{color:#DC0228;}.fill-politico-red.jsx-3251934667{color:#DC0228;}.stateface.jsx-3251934667:before{font-family:'StateFace Regular';margin-right:5px;}.stateface-replace.jsx-3251934667{text-indent:-999em;display:inline-block;position:relative;min-width:1em;}.stateface-replace.jsx-3251934667:before{position:absolute;left:0;top:0;text-indent:0;}.stateface-ak.jsx-3251934667:before{content:"A";}.stateface-al.jsx-3251934667:before{content:"B";}.stateface-ar.jsx-3251934667:before{content:"C";}.stateface-az.jsx-3251934667:before{content:"D";}.stateface-ca.jsx-3251934667:before{content:"E";}.stateface-co.jsx-3251934667:before{content:"F";}.stateface-ct.jsx-3251934667:before{content:"G";}.stateface-dc.jsx-3251934667:before{content:"y";}.stateface-de.jsx-3251934667:before{content:"H";}.stateface-fl.jsx-3251934667:before{content:"I";}.stateface-ga.jsx-3251934667:before{content:"J";}.stateface-hi.jsx-3251934667:before{content:"K";}.stateface-ia.jsx-3251934667:before{content:"L";}.stateface-id.jsx-3251934667:before{content:"M";}.stateface-il.jsx-3251934667:before{content:"N";}.stateface-in.jsx-3251934667:before{content:"O";}.stateface-ks.jsx-3251934667:before{content:"P";}.stateface-ky.jsx-3251934667:before{content:"Q";}.stateface-la.jsx-3251934667:before{content:"R";}.stateface-ma.jsx-3251934667:before{content:"S";}.stateface-md.jsx-3251934667:before{content:"T";}.stateface-me.jsx-3251934667:before{content:"U";}.stateface-mi.jsx-3251934667:before{content:"V";}.stateface-mn.jsx-3251934667:before{content:"W";}.stateface-mo.jsx-3251934667:before{content:"X";}.stateface-ms.jsx-3251934667:before{content:"Y";}.stateface-mt.jsx-3251934667:before{content:"Z";}.stateface-nc.jsx-3251934667:before{content:"a";}.stateface-nd.jsx-3251934667:before{content:"b";}.stateface-ne.jsx-3251934667:before{content:"c";}.stateface-nh.jsx-3251934667:before{content:"d";}.stateface-nj.jsx-3251934667:before{content:"e";}.stateface-nm.jsx-3251934667:before{content:"f";}.stateface-nv.jsx-3251934667:before{content:"g";}.stateface-ny.jsx-3251934667:before{content:"h";}.stateface-oh.jsx-3251934667:before{content:"i";}.stateface-ok.jsx-3251934667:before{content:"j";}.stateface-or.jsx-3251934667:before{content:"k";}.stateface-pa.jsx-3251934667:before{content:"l";}.stateface-ri.jsx-3251934667:before{content:"m";}.stateface-sc.jsx-3251934667:before{content:"n";}.stateface-sd.jsx-3251934667:before{content:"o";}.stateface-tn.jsx-3251934667:before{content:"p";}.stateface-tx.jsx-3251934667:before{content:"q";}.stateface-us.jsx-3251934667:before{content:"z";}.stateface-ut.jsx-3251934667:before{content:"r";}.stateface-va.jsx-3251934667:before{content:"s";}.stateface-vt.jsx-3251934667:before{content:"t";}.stateface-wa.jsx-3251934667:before{content:"u";}.stateface-wi.jsx-3251934667:before{content:"v";}.stateface-wv.jsx-3251934667:before{content:"w";}.stateface-wy.jsx-3251934667:before{content:"x";}.mini-balance-of-power.jsx-3251934667{position:relative;z-index:0;}.mini-balance-of-power.jsx-3251934667 a{color:#000000;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;-webkit-flex-shrink:1;-ms-flex-negative:1;flex-shrink:1;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;outline:none;positio ...
#   </style>
#   <style id="__jsx-2345505934">
# ...
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/new-hampshire/">
#       New Hampshire
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/new-jersey/">
#       New Jersey
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/new-mexico/">
#       New Mexico
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/new-york/">
#       New York
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/north-carolina/">
#       North Carolina
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/north-dakota/">
#       North Dakota
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/ohio/">
#       Ohio
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/oklahoma/">
#       Oklahoma
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/oregon/">
#       Oregon
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/pennsylvania/">
#       Pennsylvania
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/rhode-island/">
#       Rhode Island
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/south-carolina/">
#       South Carolina
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/south-dakota/">
#       South Dakota
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/tennessee/">
#       Tennessee
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/texas/">
#       Texas
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/utah/">
#       Utah
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/vermont/">
#       Vermont
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/virginia/">
#       Virginia
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/washington/">
#       Washington
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/washington-dc/">
#       Washington, D.C.
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/west-virginia/">
#       West Virginia
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/wisconsin/">
#       Wisconsin
#      </a>
#     </p>
#     <p class="jsx-3088201999 state-link">
#      <a class="jsx-2085888330" href="/2020-election/results/wyoming/">
#       Wyoming
#      </a>
#     </p>
#    </ul>
#   </div>
#   <div class="jsx-3693619050 credits">
#    <p>
#     By
#     <a href="https://twitter.com/allanjvestal">
#      Allan James Vestal
#     </a>
#     ,
#     <a href="https://twitter.com/brizandrew">
#      Andrew Briz
#     </a>
#     ,
#     <a href="https://twitter.com/annette_choi">
#      Annette Choi
#     </a>
#     ,
#     <a href="https://twitter.com/beatricezjin">
#      Beatrice Jin
#     </a>
#     ,
#     <a href="https://twitter.com/andrewmcgill">
#      Andrew McGill
#     </a>
#     and
#     <a href="https://twitter.com/mazet">
#      Lily Mihalik
#     </a>
#     .
#    </p>
#    <p>
#     Suggestions/comments?
#     <a href="/cdn-cgi/l/email-protection#dfb6b1abbaadbebcabb6a9baac9fafb0b3b6abb6bcb0f1bcb0b2">
#      Email us.
#     </a>
#    </p>
#    <p>
#     Election results provided by the Associated Press. Additional data from U.S. Census Bureau, MIT Election Lab and POLITICO reporting.
#    </p>
#   </div>
#   <footer class="jsx-2576452672 PibFooter-root footer">
#    <div class="jsx-2576452672" id="sitemap" tabindex="-1">
#    </div>
#    <nav class="jsx-2576452672 PibFooter-links-container footer__group footer__group--links">
#     <ul class="jsx-2576452672">
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://www.politico.com/about/">
#        About Us
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://www.politico.com/about/advertising">
#        Advertising
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="http://www.politico.com/subscribe/breaking-news-alerts">
#        Breaking News Alerts
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://www.politico.com/careers">
#        Careers
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://secure.politico.com/payment">
#        Credit Card Payments
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="http://edition.pagesuite-professional.co.uk/Launch.aspx?bypass=true&amp;PBID=74262970-aa07-44b3-80c8-21fa8a8ac376">
#        Digital Edition
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://www.politico.com/faq">
#        FAQ
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://www.politico.com/feedback">
#        Feedback
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://www.politico.com/politics">
#        Headlines
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://www.politico.com/gallery">
#        Photos
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="http://www.powerjobs.com/">
#        POWERJobs
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="http://www.politico.com/about/press/blog">
#        Press
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="http://www.politico.com/subscriptions">
#        Print Subscriptions
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://www.politico.com/rss">
#        RSS
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://www.politico.com/sitemap">
#        Site Map
#       </a>
#      </li>
#     </ul>
#     <ul class="jsx-2576452672">
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://www.politico.com/terms-of-service">
#        Terms of Service
#       </a>
#      </li>
#      <li class="jsx-2576452672">
#       <a class="jsx-2576452672 PibFooter-link" href="https://www.politico.com/privacy-policy">
#        Privacy Policy
#       </a>
#      </li>
#     </ul>
#    </nav>
#    <nav class="jsx-2576452672 PibFooter-legal footer__group footer__group--legal">
#     <p class="jsx-2576452672">
#      © 2020 POLITICO LLC
#     </p>
#    </nav>
#    <div class="jsx-2576452672 clear">
#    </div>
#   </footer>
#  </div>
# </div>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
# </script>
# <script id="__NEXT_DATA__" type="application/json">
#  {"props":{"pageProps":{"initialData":{"https://www.politico.com/2020-national-results/balance-of-power.json":{"url":"https://www.politico.com/2020-national-results/balance-of-power.json","lastFetched":"2020-11-12T03:19:11.714Z","lastModified":"Thu, 12 Nov 2020 02:26:35 GMT","data":{"president":{"called-winner":"dem","called-d":290,"called-r":217,"lean-d":0,"lean-r":0,"likely-d":0,"likely-r":0,"solid-d":0,"solid-r":0,"toss-up":31},"senate":{"called-winner":false,"seated-d":35,"seated-r":30,"called-d":13,"called-r":20,"lean-d":0,"lean-r":1,"likely-d":0,"likely-r":0,"solid-d":0,"solid-r":0,"toss-up":1},"house":{"called-winner":"dem","called-d":218,"called-r":202,"lean-d":4,"lean-r":1,"likely-d":1,"likely-r":0,"solid-d":0,"solid-r":1,"toss-up":8},"lastUpdated":"2020-11-12T02:26:34+00:00"},"refreshRate":15000,"polling":true},"https://www.politico.com/2020-election-chats/7a05e811-1aa5-4f67-8070-af681cfbc437/alerts/data.json":{"url":"https://www.politico.com/2020-election-chats/7a05e811-1aa5-4f67-8070-af681cfbc437/alerts/data.json","lastFetched":"2020-11-12T03:19:11.720Z","lastModified":"Wed, 04 Nov 2020 07:46:29 GMT","data":{"bundleId":"alerts","id":"7a05e811-1aa5-4f67-8070-af681cfbc437","live":false,"users":{"UVDN7QNPJ":{"first_name":"Alex","last_name":"Thompson","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/AlexThompson/profile-39e346b999.jpg","title":"Political Reporter"},"U018MK9UYCR":{"first_name":"Annette","last_name":"Choi","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/AnnetteChoi/profile-ef02803bb4.jpg","title":""},"UVDNUTTNC":{"first_name":"Marc","last_name":"Caputo","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/MarcCaputo/T145T49MK-UVDNUTTNC-0951db4cfcad-512.png","title":"Biden Campaign Reporter"},"UV0V7H87L":{"first_name":"Natasha","last_name":"Korecki","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/NatashaKorecki/profile-fbb6a0c87a.jpg","title":"National Political Correspondent"},"UVD92PCRJ":{"first_name":"Charlie","last_name":"Mahtesian","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/CharlieMahtesian/profile-631c75b319.jpg","title":"Senior politics editor"},"UVD9PAXPW":{"first_name":"Andrew","last_name":"Atterbury","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/AndrewAtterbury/profile-6fa3c468cf.jpg","title":""},"U019VF5MFCN":{"first_name":"Gabrielle","last_name":"Wanneh","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/GabrielleWanneh/profile-a9a7f78a5c.jpg","title":""},"UV28QRBPV":{"first_name":"Christopher","last_name":"Cadelago","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/ChristopherCadelago/profile-27428e1bbd.jpg","title":"National Political Reporter"},"UV0UTHPD0":{"first_name":"David","last_name":"Siders","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/DavidSiders/profile-643987e1e0.jpg","title":"National political correspondent"},"UV3LSC2EM":{"first_name":"Steven","last_name":"Shepard","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/StevenShepard/profile-3e157e64aa.jpg","title":"Senior campaigns and elections editor"},"UV297QP6X":{"first_name":"Nancy","last_name":"Scola","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/NancyScola/profile-7ff07c54a6.jpg","title":"senior technology reporter"},"U0101K2M91V":{"first_name":"tweyant","last_name":"","image":"https://s3.amazonaws.com/interactives.politico.com/interactives/apps/labs/slackchat/users/tweyant/profile-c3def00e79.jpg","title":""},"UVD92MH36":{"first_name":"Carla","last_name":"Alena Marinucci","imag ...
# </script>
# <script nomodule="" src="/2020-election/results/_next/static/runtime/polyfills-28f287af14148634a4bf.js">
# </script>
# <script async="" data-next-page="/_app" src="/2020-election/results/_next/static/ookHP4AtUcEq4iVOyqXPR/pages/_app.js">
# </script>
# <script async="" data-next-page="/house" src="/2020-election/results/_next/static/ookHP4AtUcEq4iVOyqXPR/pages/house.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/runtime/webpack-0da7803b01c6aab302c7.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/framework.dcb13c6c2896e64b7ea5.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/commons.5cd6838afae58f8f8e87.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/c50ac3d8a66fb307f7f9036de1b55045392a5954.12eda1bd7e546020f8e7.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/00f5ebd0fabb2bdee7ac1ac5d8f036bf490762e3.7a9ad674ab11e50ced25.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/fc8d6d8698d6869bb695d2f5dac3bf9cb8b30d16.b5f0a7a2388ae006fa3e.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/a6adb3b0b257ceeb71dd59e0d09fdd82935f298f.8bb82c1f99afb37420bb.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/runtime/main-706e444445fd8fec6e08.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/9598fa14.48032d94b585afb50ac1.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/0320ba56.cfb57a8b96f3b999d145.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/b5a2aaf6.645f125407133e30fdd5.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/37120036.cef276aaa8ea78bc8997.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/1832c932f39855380fa904e70e7e680fdf0fac33.b2663fac0f7da312d48e.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/587d8c97d56c7309711fcf17bed99abab4475cb8.77860537361bebd0445c.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/f56ffd422b6f56979f47a1253957f552f20d8ec1.14b65a6a6c8068d295c9.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/b8d007847897f095c6d8bab8e8d1471a26941ecb.331bebd308205da327c3.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/cb169220ee6a99b5e455a5d3d64130af25c95da1.8573dd299f92b438ed7f.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/c7348c6f43d4d389403fb62d6829c3561a663d43.792597c004d33aadb77d.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/f5cfb43b1b1b2d05e15359ba0ac867c07cf293bf.9e14ee493f40baf40676.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/b56cc8cc777fa766ece872936602a9e7be0127ea.c28eb599321f1bfb33f5.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/b7b9d29ca6a3217730f9f0e15f1454d76be7268d.6ef789447c45e4555154.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/b97b7c8883bd44d773cb2e4c164ef576162addbe.e1c0fde5abe5ea8b08c0.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/0c8ef19524b2998c6c0f9417feeb8c55df13c70b.3f25959400240b1d75eb.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/e3c4c3357f6eb6557f3eed604592be73b8099826.c47c4c6866355841eab2.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/80f1ce362748fb162861803bdf95f120093e5a3d.422fbae88876f26dc467.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/chunks/5c25a6f799cc4ab6f45ce0cc9d9e71637e0c3f10.4ab6a50bd991a3bdb638.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/ookHP4AtUcEq4iVOyqXPR/_buildManifest.js">
# </script>
# <script async="" src="/2020-election/results/_next/static/ookHP4AtUcEq4iVOyqXPR/_ssgManifest.js">
# </script>

# %%
# retrieve all state links in a list
state_links = soup.find('ul','jsx-3088201999 state-link-list').find_all("p")
# drop the first element since that's "all states"
state_links = state_links[1:len(state_links)]

# %%
# extract the urls from state_links
state_urls = [x.find("a").get('href') for x in state_links]
# add in "politico.com" to each url
state_urls = ["http://politico.com"+x+'house' for x in state_urls]

# %%
state_urls
# Out:
# ['http://politico.com/2020-election/results/alabama/house',
#  'http://politico.com/2020-election/results/alaska/house',
#  'http://politico.com/2020-election/results/arizona/house',
#  'http://politico.com/2020-election/results/arkansas/house',
#  'http://politico.com/2020-election/results/california/house',
#  'http://politico.com/2020-election/results/colorado/house',
#  'http://politico.com/2020-election/results/connecticut/house',
#  'http://politico.com/2020-election/results/delaware/house',
#  'http://politico.com/2020-election/results/florida/house',
#  'http://politico.com/2020-election/results/georgia/house',
#  'http://politico.com/2020-election/results/hawaii/house',
#  'http://politico.com/2020-election/results/idaho/house',
#  'http://politico.com/2020-election/results/illinois/house',
#  'http://politico.com/2020-election/results/indiana/house',
#  'http://politico.com/2020-election/results/iowa/house',
#  'http://politico.com/2020-election/results/kansas/house',
#  'http://politico.com/2020-election/results/kentucky/house',
#  'http://politico.com/2020-election/results/louisiana/house',
#  'http://politico.com/2020-election/results/maine/house',
#  'http://politico.com/2020-election/results/maryland/house',
#  'http://politico.com/2020-election/results/massachusetts/house',
#  'http://politico.com/2020-election/results/michigan/house',
#  'http://politico.com/2020-election/results/minnesota/house',
#  'http://politico.com/2020-election/results/mississippi/house',
#  'http://politico.com/2020-election/results/missouri/house',
#  'http://politico.com/2020-election/results/montana/house',
#  'http://politico.com/2020-election/results/nebraska/house',
#  'http://politico.com/2020-election/results/nevada/house',
#  'http://politico.com/2020-election/results/new-hampshire/house',
#  'http://politico.com/2020-election/results/new-jersey/house',
#  'http://politico.com/2020-election/results/new-mexico/house',
#  'http://politico.com/2020-election/results/new-york/house',
#  'http://politico.com/2020-election/results/north-carolina/house',
#  'http://politico.com/2020-election/results/north-dakota/house',
#  'http://politico.com/2020-election/results/ohio/house',
#  'http://politico.com/2020-election/results/oklahoma/house',
#  'http://politico.com/2020-election/results/oregon/house',
#  'http://politico.com/2020-election/results/pennsylvania/house',
#  'http://politico.com/2020-election/results/rhode-island/house',
#  'http://politico.com/2020-election/results/south-carolina/house',
#  'http://politico.com/2020-election/results/south-dakota/house',
#  'http://politico.com/2020-election/results/tennessee/house',
#  'http://politico.com/2020-election/results/texas/house',
#  'http://politico.com/2020-election/results/utah/house',
#  'http://politico.com/2020-election/results/vermont/house',
#  'http://politico.com/2020-election/results/virginia/house',
#  'http://politico.com/2020-election/results/washington/house',
#  'http://politico.com/2020-election/results/washington-dc/house',
#  'http://politico.com/2020-election/results/west-virginia/house',
#  'http://politico.com/2020-election/results/wisconsin/house',
#  'http://politico.com/2020-election/results/wyoming/house']

# %%
state_url = state_urls[0]
state = re.sub('/house','',re.sub('.*results/','',state_url))
# retrieve state
req = requests.get(state_url)
soup = BeautifulSoup(req.content, 'html.parser')
# create a list of all result blocks
result_blocks = soup.find_all('div','smaller-leaderboard-container')

# %%
####################################################################################################################
column_names = ["state","district","candidate","party","votes"]
district = result_blocks[0].find('div').get('id')
result_table = result_blocks[0].find('div','results-table').find('table').find('tbody').find_all('tr')

# define a function to parse rows
def parse_row(row,state,district):
    # first td contains candidate name and party, so extract that
    name_party = row.find_all('td')[0].find_all('div')
    name = name_party[0].get_text()
    party = name_party[1].get_text()
    # text of second td contains votes
    votes = row.find('div','candidate-votes-next-to-percent').get_text()
    return([state,district,name,party,votes])
table_data_list = []
for row in result_table:
    table_data_list.append(parse_row(row,state,district))
pd.DataFrame(table_data_list,columns = column_names)
# Out:
#      state district candidate party    votes
# 0  alabama     cd01      Carl   gop  210,636
# 1  alabama     cd01  Averhart   dem  115,592

# %%
# define a function that takes a state_url as an argument, and returns a dataframe of all election results for that state
def get_state_results(state_url):
    # store name of state
    state = re.sub('/house','',re.sub('.*results/','',state_url))
    # retrieve state
    req = requests.get(state_url)
    if req.status_code!=404:
        soup = BeautifulSoup(req.content, 'html.parser')
        # create a list of all result blocks
        result_blocks = soup.find_all('div','smaller-leaderboard-container')
        # create a blank list to store results for each district in the state
        all_districts = []
        for result_block in result_blocks:
            # store the name of district
            district = result_block.find('div').get('id')
            # isolate table body, parse to list of rows
            result_table = result_block.find('div','results-table').find('table').find('tbody').find_all('tr')
            # iterate through rows of result_table, use parse_row to extract info
            table_row_list = [parse_row(row,state,district=district) for row in result_table]
            # convert table_row_list to pandas
            temp_df = pd.DataFrame(table_row_list,columns = column_names)
            # add pandas frame to all_districts
            all_districts.append(temp_df)
        return(pd.concat(all_districts))
get_state_results(state_url)
# Out:
#      state district    candidate party    votes
# 0  alabama     cd01         Carl   gop  210,636
# 1  alabama     cd01     Averhart   dem  115,592
# 0  alabama     cd02        Moore   gop  197,329
# 1  alabama     cd02  Harvey-Hall   dem  104,592
# 0  alabama     cd03      Rogers*   gop  216,700
# 1  alabama     cd03      Winfrey   dem  103,874
# 0  alabama     cd04    Aderholt*   gop  257,201
# 1  alabama     cd04    Neighbors   dem   52,688
# 0  alabama     cd05      Brooks*   gop        0
# 0  alabama     cd06      Palmer*   gop        0
# 0  alabama     cd07      Sewell*   dem        0

# %%
# apply get_state_result for all states
all_state_results = [get_state_results(state_url) for state_url in state_urls]

# %%
all_cd_results = pd.concat(all_state_results).reset_index()
all_cd_results[['state','district','candidate','party','votes']].to_csv('results by cd 2020.csv',
                                                                       index=False)

# %%
state_url
# Out:
# 'http://politico.com/2020-election/results/alabama/house'

# %%
requests.get('https://www.politico.com/2020-election/results/washington-dc/house').status_code
# Out:
# 404

# %%
all_cd_results
# Out:
#      index      state district    candidate party    votes
# 0        0    alabama     cd01         Carl   gop  210,636
# 1        1    alabama     cd01     Averhart   dem  115,592
# 2        0    alabama     cd02        Moore   gop  197,329
# 3        1    alabama     cd02  Harvey-Hall   dem  104,592
# 4        0    alabama     cd03      Rogers*   gop  216,700
# ..     ...        ...      ...          ...   ...      ...
# 853      1  wisconsin     cd07       Zunker   dem  162,729
# 854      0  wisconsin     cd08   Gallagher*   gop  267,862
# 855      1  wisconsin     cd08        Stuck   dem  150,824
# 856      0    wyoming     cd00      Cheney*   gop  185,602
# 857      1    wyoming     cd00    Grey Bull   dem   66,539
#
# [858 rows x 6 columns]
